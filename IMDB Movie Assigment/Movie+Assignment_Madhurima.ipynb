# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv("Movie+Assignment+Data.csv") # Write your code for importing the csv file here
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 5038  ...                  6.0  English   Canada             NaN          NaN
# 5039  ...                359.0  English      USA           TV-14          NaN
# 5040  ...                  3.0  English      USA             NaN       1400.0
# 5041  ...                  9.0  English      USA           PG-13          NaN
# 5042  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 5038      2013.0                  470.0        7.7           NaN
# 5039         NaN                  593.0        7.5         16.00
# 5040      2013.0                    0.0        6.3           NaN
# 5041      2012.0                  719.0        6.3          2.35
# 5042      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 5038                   84
# 5039                32000
# 5040                   16
# 5041                  660
# 5042                  456
#
# [5043 rows x 28 columns]

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
print(movies.shape)
print(movies.info())
movies.head()
# Out:
# (5043, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
#  13  cast_total_facebook_likes  5043 non-null   int64
#  14  actor_3_name               5020 non-null   object
#  15  facenumber_in_poster       5030 non-null   float64
#  16  plot_keywords              4890 non-null   object
#  17  movie_imdb_link            5043 non-null   object
#  18  num_user_for_reviews       5022 non-null   float64
#  19  language                   5031 non-null   object
#  20  country                    5038 non-null   object
#  21  content_rating             4740 non-null   object
#  22  budget                     4551 non-null   float64
#  23  title_year                 4935 non-null   float64
#  24  actor_2_facebook_likes     5030 non-null   float64
#  25  imdb_score                 5043 non-null   float64
#  26  aspect_ratio               4714 non-null   float64
#  27  movie_facebook_likes       5043 non-null   int64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.1+ MB
# None
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
column_nullcount = movies.isnull().sum()
print(column_nullcount)
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
row_nullcount = movies.isnull().sum(axis = 1)
print(row_nullcount)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
#'column_nullcount' is the column-wise null count as defined above
null_percentage = round((column_nullcount/len(movies.index))*100, 2)  
print(null_percentage)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# movie_facebook_likes          0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations
drop_list = ['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords']
movies = movies.drop(drop_list ,axis = 1)
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# 3                             The Dark Knight Rises           1144337
# 4  Star Wars: Episode VII - The Force Awakens    ...                8
#
#    num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                3054.0  English  237000000.0      2009.0         7.9
# 1                1238.0  English  300000000.0      2007.0         7.1
# 2                 994.0  English  245000000.0      2015.0         6.8
# 3                2701.0  English  250000000.0      2012.0         8.5
# 4                   NaN      NaN          NaN         NaN         7.1
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 4                     0

# %%
# Inspection for null values.
round(movies.isnull().sum()/len(movies.index)*100, 2)
# Out:
# director_name              2.06
# num_critic_for_reviews     0.99
# gross                     17.53
# genres                     0.00
# actor_1_name               0.14
# movie_title                0.00
# num_voted_users            0.00
# num_user_for_reviews       0.42
# language                   0.24
# budget                     9.76
# title_year                 2.14
# imdb_score                 0.00
# movie_facebook_likes       0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here.

# According to the inspection done above, the columns 'gross' & 'budget' have more than 5% of null values.

movies = movies.dropna(subset = ['gross','budget'])
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 5     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 5                               John Carter            212204
#
#    num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                3054.0  English  237000000.0      2009.0         7.9
# 1                1238.0  English  300000000.0      2007.0         7.1
# 2                 994.0  English  245000000.0      2015.0         6.8
# 3                2701.0  English  250000000.0      2012.0         8.5
# 5                 738.0  English  263700000.0      2012.0         6.6
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 5                 24000

# %%
# Further inspection for null values.
round(100*(movies.isnull().sum()/len(movies.index)), 2)
# Out:
# director_name             0.00
# num_critic_for_reviews    0.03
# gross                     0.00
# genres                    0.00
# actor_1_name              0.08
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.08
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
#Inspection of null values in the column - 'language'
movies[movies['language'].isnull()]
# Out:
#            director_name  num_critic_for_reviews      gross  \
# 3086    Christopher Cain                    43.0  1066555.0
# 4110  Michael Landon Jr.                     5.0   252726.0
# 4958   Harry F. Millarde                     1.0  3000000.0
#
#                              genres             actor_1_name  \
# 3086  Drama|History|Romance|Western                Jon Gries
# 4110           Drama|Family|Western  William Morgan Sheppard
# 4958                    Crime|Drama             Stephen Carr
#
#                           movie_title  num_voted_users  num_user_for_reviews  \
# 3086                  September Dawn              2618                 111.0
# 4110              Love's Abiding Joy              1289                  18.0
# 4958  Over the Hill to the Poorhouse                 5                   1.0
#
#      language      budget  title_year  imdb_score  movie_facebook_likes
# 3086      NaN  11000000.0      2007.0         5.8                   411
# 4110      NaN   3000000.0      2006.0         7.2                    76
# 4958      NaN    100000.0      1920.0         4.8                     0

# %%
# Write your code for filling the NaN values in the 'language' column here
movies["language"].fillna("English", inplace = True) 
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 5     Andrew Stanton                   462.0   73058679.0
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 5                               John Carter            212204
#
#    num_user_for_reviews language       budget  title_year  imdb_score  \
# 0                3054.0  English  237000000.0      2009.0         7.9
# 1                1238.0  English  300000000.0      2007.0         7.1
# 2                 994.0  English  245000000.0      2015.0         6.8
# 3                2701.0  English  250000000.0      2012.0         8.5
# 5                 738.0  English  263700000.0      2012.0         6.6
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 5                 24000

# %%
#Further inspection for null values.
round((movies.isnull().sum()/len(movies.index))*100,2)
# Out:
# director_name             0.00
# num_critic_for_reviews    0.03
# gross                     0.00
# genres                    0.00
# actor_1_name              0.08
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
retained = len(movies.index)
print(retained)
# Out:
# 3891

# %%
# Write your code for checking percentage of retained rows here
retainedp = round(100*(retained/5043),2)
print(retainedp)
# Out:
# 77.16

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
movies.gross = round(movies['gross']/100000, 2)
movies.budget = round(movies['budget']/1000000, 2)
movies.head()
# Out:
#        director_name  num_critic_for_reviews    gross  \
# 0      James Cameron                   723.0  7605.06
# 1     Gore Verbinski                   302.0  3094.04
# 2         Sam Mendes                   602.0  2000.74
# 3  Christopher Nolan                   813.0  4481.31
# 5     Andrew Stanton                   462.0   730.59
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 5          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                  movie_title  num_voted_users  \
# 0                                    Avatar            886204
# 1  Pirates of the Caribbean: At World's End            471220
# 2                                   Spectre            275868
# 3                     The Dark Knight Rises           1144337
# 5                               John Carter            212204
#
#    num_user_for_reviews language  budget  title_year  imdb_score  \
# 0                3054.0  English   237.0      2009.0         7.9
# 1                1238.0  English   300.0      2007.0         7.1
# 2                 994.0  English   245.0      2015.0         6.8
# 3                2701.0  English   250.0      2012.0         8.5
# 5                 738.0  English   263.7      2012.0         6.6
#
#    movie_facebook_likes
# 0                 33000
# 1                     0
# 2                 85000
# 3                164000
# 5                 24000

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
movies['Profit'] = movies['gross'] - movies['budget']
movies
# Out:
#           director_name  num_critic_for_reviews    gross  \
# 0         James Cameron                   723.0  7605.06
# 1        Gore Verbinski                   302.0  3094.04
# 2            Sam Mendes                   602.0  2000.74
# 3     Christopher Nolan                   813.0  4481.31
# 5        Andrew Stanton                   462.0   730.59
# ...                 ...                     ...      ...
# 5033      Shane Carruth                   143.0     4.25
# 5034   Neill Dela Llana                    35.0     0.70
# 5035   Robert Rodriguez                    56.0    20.41
# 5037       Edward Burns                    14.0     0.05
# 5042           Jon Gunn                    43.0     0.85
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# 3                         Action|Thriller        Tom Hardy
# 5                 Action|Adventure|Sci-Fi     Daryl Sabara
# ...                                   ...              ...
# 5033                Drama|Sci-Fi|Thriller    Shane Carruth
# 5034                             Thriller      Ian Gamazon
# 5035  Action|Crime|Drama|Romance|Thriller  Carlos Gallardo
# 5037                         Comedy|Drama      Kerry Bishé
# 5042                          Documentary      John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# 2                                      Spectre            275868
# 3                        The Dark Knight Rises           1144337
# 5                                  John Carter            212204
# ...                                         ...              ...
# 5033                                    Primer             72639
# 5034                                    Cavite               589
# 5035                               El Mariachi             52055
# 5037                                 Newlyweds              1338
# 5042                         My Date with Drew              4285
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 0                   3054.0  English  237.00      2009.0         7.9
# 1                   1238.0  English  300.00      2007.0         7.1
# 2                    994.0  English  245.00      2015.0         6.8
# 3                   2701.0  English  250.00      2012.0         8.5
# 5                    738.0  English  263.70      2012.0         6.6
# ...                    ...      ...     ...         ...         ...
# 5033                 371.0  English    0.01      2004.0         7.0
# 5034                  35.0  English    0.01      2005.0         6.3
# 5035                 130.0  Spanish    0.01      1992.0         6.9
# 5037                  14.0  English    0.01      2011.0         6.4
# 5042                  84.0  English    0.00      2004.0         6.6
#
#       movie_facebook_likes   Profit
# 0                    33000  7368.06
# 1                        0  2794.04
# 2                    85000  1755.74
# 3                   164000  4231.31
# 5                    24000   466.89
# ...                    ...      ...
# 5033                 19000     4.24
# 5034                    74     0.69
# 5035                     0    20.40
# 5037                   413     0.04
# 5042                   456     0.85
#
# [3891 rows x 14 columns]

# %%
# Write your code for sorting the dataframe here
movies = movies.sort_values(by = 'Profit', ascending = False)
movies
# Out:
#         director_name  num_critic_for_reviews    gross  \
# 0       James Cameron                   723.0  7605.06
# 26      James Cameron                   315.0  6586.72
# 29    Colin Trevorrow                   644.0  6521.77
# 794       Joss Whedon                   703.0  6232.80
# 17        Joss Whedon                   703.0  6232.80
# ...               ...                     ...      ...
# 2334  Katsuhiro Ôtomo                   105.0     4.10
# 2323   Hayao Miyazaki                   174.0    22.98
# 3005     Lajos Koltai                    73.0     1.96
# 3859   Chan-wook Park                   202.0     2.12
# 2988     Joon-ho Bong                   363.0    22.01
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 26                                        Drama|Romance    Leonardo DiCaprio
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 794                             Action|Adventure|Sci-Fi      Chris Hemsworth
# 17                              Action|Adventure|Sci-Fi      Chris Hemsworth
# ...                                                 ...                  ...
# 2334  Action|Adventure|Animation|Family|Sci-Fi|Thriller     William Hootkins
# 2323                        Adventure|Animation|Fantasy        Minnie Driver
# 3005                                  Drama|Romance|War         Marcell Nagy
# 3859                                        Crime|Drama         Min-sik Choi
# 2988                         Comedy|Drama|Horror|Sci-Fi            Doona Bae
#
#              movie_title  num_voted_users  num_user_for_reviews   language  \
# 0                Avatar            886204                3054.0    English
# 26              Titanic            793059                2528.0    English
# 29       Jurassic World            418214                1290.0    English
# 794        The Avengers            995415                1722.0    English
# 17         The Avengers            995415                1722.0    English
# ...                  ...              ...                   ...        ...
# 2334           Steamboy             13727                  79.0   Japanese
# 2323  Princess Mononoke            221552                 570.0   Japanese
# 3005           Fateless              5603                  45.0  Hungarian
# 3859     Lady Vengeance             53508                 131.0     Korean
# 2988           The Host             68883                 279.0     Korean
#
#         budget  title_year  imdb_score  movie_facebook_likes    Profit
# 0       237.00      2009.0         7.9                 33000   7368.06
# 26      200.00      1997.0         7.7                 26000   6386.72
# 29      150.00      2015.0         7.0                150000   6371.77
# 794     220.00      2012.0         8.1                123000   6012.80
# 17      220.00      2012.0         8.1                123000   6012.80
# ...        ...         ...         ...                   ...       ...
# 2334   2127.52      2004.0         6.9                   973  -2123.42
# 2323   2400.00      1997.0         8.4                 11000  -2377.02
# 3005   2500.00      2005.0         7.1                   607  -2498.04
# 3859   4200.00      2005.0         7.7                  4000  -4197.88
# 2988  12215.50      2006.0         7.0                  7000 -12193.49
#
# [3891 rows x 14 columns]

# %%
# Write code for profit vs budget plot here
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

sns.jointplot('budget','Profit',movies)
plt.title('Profit vs Budget')
plt.show()

# %% [markdown]
# We can see that the outlier is a **Korean** Movie, **Joon-ho Bong**, that made a huge loss.

# %%
top10 = movies[0:10]
top10 # Write your code to get the top 10 profiting movies here
# Out:
#           director_name  num_critic_for_reviews    gross  \
# 0         James Cameron                   723.0  7605.06
# 26        James Cameron                   315.0  6586.72
# 29      Colin Trevorrow                   644.0  6521.77
# 794         Joss Whedon                   703.0  6232.80
# 17          Joss Whedon                   703.0  6232.80
# 66    Christopher Nolan                   645.0  5333.16
# 240        George Lucas                   320.0  4745.45
# 3024       George Lucas                   282.0  4609.36
# 8           Joss Whedon                   635.0  4589.92
# 3080   Steven Spielberg                   215.0  4349.49
#
#                                 genres         actor_1_name  \
# 0      Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 26                       Drama|Romance    Leonardo DiCaprio
# 29    Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 794            Action|Adventure|Sci-Fi      Chris Hemsworth
# 17             Action|Adventure|Sci-Fi      Chris Hemsworth
# 66         Action|Crime|Drama|Thriller       Christian Bale
# 240    Action|Adventure|Fantasy|Sci-Fi      Natalie Portman
# 3024   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 8              Action|Adventure|Sci-Fi      Chris Hemsworth
# 3080                     Family|Sci-Fi         Henry Thomas
#
#                                      movie_title  num_voted_users  \
# 0                                        Avatar            886204
# 26                                      Titanic            793059
# 29                               Jurassic World            418214
# 794                                The Avengers            995415
# 17                                 The Avengers            995415
# 66                              The Dark Knight           1676169
# 240   Star Wars: Episode I - The Phantom Menace            534658
# 3024         Star Wars: Episode IV - A New Hope            911097
# 8                       Avengers: Age of Ultron            462669
# 3080                 E.T. the Extra-Terrestrial            281842
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 0                   3054.0  English   237.0      2009.0         7.9
# 26                  2528.0  English   200.0      1997.0         7.7
# 29                  1290.0  English   150.0      2015.0         7.0
# 794                 1722.0  English   220.0      2012.0         8.1
# 17                  1722.0  English   220.0      2012.0         8.1
# 66                  4667.0  English   185.0      2008.0         9.0
# 240                 3597.0  English   115.0      1999.0         6.5
# 3024                1470.0  English    11.0      1977.0         8.7
# 8                   1117.0  English   250.0      2015.0         7.5
# 3080                 515.0  English    10.5      1982.0         7.9
#
#       movie_facebook_likes   Profit
# 0                    33000  7368.06
# 26                   26000  6386.72
# 29                  150000  6371.77
# 794                 123000  6012.80
# 17                  123000  6012.80
# 66                   37000  5148.16
# 240                  13000  4630.45
# 3024                 33000  4598.36
# 8                   118000  4339.92
# 3080                 34000  4338.99

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
#Write code for dropping duplicate values.

#Finding whether a in movies row is duplicate
#and assigning it to a column named “is_dup” - duplicated() tags in boolean

movies['is_dup'] = movies.duplicated()

#Finding the rows with value 'is_dup' = True
indexNames = movies[ movies['is_dup'] == True ].index 

#dropping the rows which have 'is_dup' = True, so the duplicated values are dropped.
movies = movies.drop(indexNames) 

#dropping the extra column created - 'is_dup'
movies = movies.drop(['is_dup'], axis = 1) 
movies.head()
# Out:
#          director_name  num_critic_for_reviews    gross  \
# 0        James Cameron                   723.0  7605.06
# 26       James Cameron                   315.0  6586.72
# 29     Colin Trevorrow                   644.0  6521.77
# 794        Joss Whedon                   703.0  6232.80
# 66   Christopher Nolan                   645.0  5333.16
#
#                                genres         actor_1_name       movie_title  \
# 0     Action|Adventure|Fantasy|Sci-Fi          CCH Pounder           Avatar
# 26                      Drama|Romance    Leonardo DiCaprio          Titanic
# 29   Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard   Jurassic World
# 794           Action|Adventure|Sci-Fi      Chris Hemsworth     The Avengers
# 66        Action|Crime|Drama|Thriller       Christian Bale  The Dark Knight
#
#      num_voted_users  num_user_for_reviews language  budget  title_year  \
# 0             886204                3054.0  English   237.0      2009.0
# 26            793059                2528.0  English   200.0      1997.0
# 29            418214                1290.0  English   150.0      2015.0
# 794           995415                1722.0  English   220.0      2012.0
# 66           1676169                4667.0  English   185.0      2008.0
#
#      imdb_score  movie_facebook_likes   Profit
# 0           7.9                 33000  7368.06
# 26          7.7                 26000  6386.72
# 29          7.0                150000  6371.77
# 794         8.1                123000  6012.80
# 66          9.0                 37000  5148.16

# %%
#Inspection
print(movies.shape)
print(movies.info())f
# Out:
# (3856, 14)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3856 entries, 0 to 2988
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   director_name           3856 non-null   object
#  1   num_critic_for_reviews  3855 non-null   float64
#  2   gross                   3856 non-null   float64
#  3   genres                  3856 non-null   object
#  4   actor_1_name            3853 non-null   object
#  5   movie_title             3856 non-null   object
#  6   num_voted_users         3856 non-null   int64
#  7   num_user_for_reviews    3856 non-null   float64
#  8   language                3856 non-null   object
#  9   budget                  3856 non-null   float64
#  10  title_year              3856 non-null   float64
#  11  imdb_score              3856 non-null   float64
#  12  movie_facebook_likes    3856 non-null   int64
#  13  Profit                  3856 non-null   float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 451.9+ KB
# None

# %%
# Write code for repeating subtask 2 here
top10 = movies.head(10)
top10
# Out:
#           director_name  num_critic_for_reviews    gross  \
# 0         James Cameron                   723.0  7605.06
# 26        James Cameron                   315.0  6586.72
# 29      Colin Trevorrow                   644.0  6521.77
# 794         Joss Whedon                   703.0  6232.80
# 66    Christopher Nolan                   645.0  5333.16
# 240        George Lucas                   320.0  4745.45
# 3024       George Lucas                   282.0  4609.36
# 8           Joss Whedon                   635.0  4589.92
# 3080   Steven Spielberg                   215.0  4349.49
# 3     Christopher Nolan                   813.0  4481.31
#
#                                 genres         actor_1_name  \
# 0      Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 26                       Drama|Romance    Leonardo DiCaprio
# 29    Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 794            Action|Adventure|Sci-Fi      Chris Hemsworth
# 66         Action|Crime|Drama|Thriller       Christian Bale
# 240    Action|Adventure|Fantasy|Sci-Fi      Natalie Portman
# 3024   Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 8              Action|Adventure|Sci-Fi      Chris Hemsworth
# 3080                     Family|Sci-Fi         Henry Thomas
# 3                      Action|Thriller            Tom Hardy
#
#                                      movie_title  num_voted_users  \
# 0                                        Avatar            886204
# 26                                      Titanic            793059
# 29                               Jurassic World            418214
# 794                                The Avengers            995415
# 66                              The Dark Knight           1676169
# 240   Star Wars: Episode I - The Phantom Menace            534658
# 3024         Star Wars: Episode IV - A New Hope            911097
# 8                       Avengers: Age of Ultron            462669
# 3080                 E.T. the Extra-Terrestrial            281842
# 3                         The Dark Knight Rises           1144337
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 0                   3054.0  English   237.0      2009.0         7.9
# 26                  2528.0  English   200.0      1997.0         7.7
# 29                  1290.0  English   150.0      2015.0         7.0
# 794                 1722.0  English   220.0      2012.0         8.1
# 66                  4667.0  English   185.0      2008.0         9.0
# 240                 3597.0  English   115.0      1999.0         6.5
# 3024                1470.0  English    11.0      1977.0         8.7
# 8                   1117.0  English   250.0      2015.0         7.5
# 3080                 515.0  English    10.5      1982.0         7.9
# 3                   2701.0  English   250.0      2012.0         8.5
#
#       movie_facebook_likes   Profit
# 0                    33000  7368.06
# 26                   26000  6386.72
# 29                  150000  6371.77
# 794                 123000  6012.80
# 66                   37000  5148.16
# 240                  13000  4630.45
# 3024                 33000  4598.36
# 8                   118000  4339.92
# 3080                 34000  4338.99
# 3                   164000  4231.31

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'

Top_25 = movies[movies['num_voted_users'] > 25000] #condition for num_voted_users > 25000

IMDb_Top_250 = Top_25.sort_values(by = 'imdb_score', ascending = False).head(250)
IMDb_Top_250['Rank'] = range(1, 251)
IMDb_Top_250.set_index('Rank', inplace = True)

IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews    gross  \
# Rank
# 1           Frank Darabont                   199.0   283.41
# 2     Francis Ford Coppola                   208.0  1348.22
# 3        Christopher Nolan                   645.0  5333.16
# 4     Francis Ford Coppola                   149.0   573.00
# 5            Peter Jackson                   328.0  3770.19
# ...                    ...                     ...      ...
# 246   Paul Thomas Anderson                   153.0   263.85
# 247          Peter Jackson                   509.0  2583.55
# 248        Cristian Mungiu                   233.0    11.86
# 249       Fabián Bielinsky                    94.0    12.21
# 250        Paul Greengrass                   491.0  1071.01
#
#                               genres      actor_1_name  \
# Rank
# 1                        Crime|Drama    Morgan Freeman
# 2                        Crime|Drama         Al Pacino
# 3        Action|Crime|Drama|Thriller    Christian Bale
# 4                        Crime|Drama    Robert De Niro
# 5     Action|Adventure|Drama|Fantasy     Orlando Bloom
# ...                              ...               ...
# 246                            Drama       Don Cheadle
# 247                Adventure|Fantasy      Aidan Turner
# 248                            Drama  Anamaria Marinca
# 249             Crime|Drama|Thriller     Ricardo Darín
# 250         Biography|Drama|Thriller         Tom Hanks
#
#                                          movie_title  num_voted_users  \
# Rank
# 1                          The Shawshank Redemption           1689764
# 2                                     The Godfather           1155770
# 3                                   The Dark Knight           1676169
# 4                            The Godfather: Part II            790926
# 5     The Lord of the Rings: The Return of the King           1215718
# ...                                              ...              ...
# 246                                   Boogie Nights            189032
# 247             The Hobbit: The Desolation of Smaug            483540
# 248                    4 Months, 3 Weeks and 2 Days             44763
# 249                                     Nine Queens             38215
# 250                                Captain Phillips            323353
#
#       num_user_for_reviews  language  budget  title_year  imdb_score  \
# Rank
# 1                   4144.0   English   25.00      1994.0         9.3
# 2                   2238.0   English    6.00      1972.0         9.2
# 3                   4667.0   English  185.00      2008.0         9.0
# 4                    650.0   English   13.00      1974.0         9.0
# 5                   3189.0   English   94.00      2003.0         8.9
# ...                    ...       ...     ...         ...         ...
# 246                  560.0   English   15.00      1997.0         7.9
# 247                  951.0   English  225.00      2013.0         7.9
# 248                  172.0  Romanian    0.59      2007.0         7.9
# 249                  125.0   Spanish    1.50      2000.0         7.9
# 250                  527.0   English   55.00      2013.0         7.9
#
#       movie_facebook_likes   Profit
# Rank
# 1                   108000   258.41
# 2                    43000  1342.22
# 3                    37000  5148.16
# 4                    14000   560.00
# 5                    16000  3676.19
# ...                    ...      ...
# 246                      0   248.85
# 247                  83000  2358.55
# 248                  14000    11.27
# 249                      0    10.71
# 250                  65000  1016.01
#
# [250 rows x 14 columns]

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language'] != 'English']
Top_Foreign_Lang_Film
# Out:
#                          director_name  num_critic_for_reviews    gross  \
# Rank
# 6                         Sergio Leone                   181.0    61.00
# 17                      Akira Kurosawa                   153.0     2.69
# 20                  Fernando Meirelles                   214.0    75.63
# 24                      Hayao Miyazaki                   246.0   100.50
# 36                        Majid Majidi                    46.0     9.25
# 40    Florian Henckel von Donnersmarck                   215.0   112.85
# 50                      Asghar Farhadi                   354.0    70.98
# 52                      Chan-wook Park                   305.0    21.81
# 54                  Jean-Pierre Jeunet                   242.0   332.02
# 55                      Hayao Miyazaki                   174.0    22.98
# 57                   Wolfgang Petersen                    96.0   114.33
# 59                      S.S. Rajamouli                    44.0    64.98
# 65                   Thomas Vinterberg                   349.0     6.11
# 75                 Oliver Hirschbiegel                   192.0    55.02
# 82                          Fritz Lang                   260.0     0.26
# 86                      Hayao Miyazaki                   212.0    47.10
# 89                Juan José Campanella                   262.0   201.67
# 98                    Denis Villeneuve                   226.0    68.57
# 104                 Guillermo del Toro                   406.0   376.23
# 115                 Alejandro Amenábar                   157.0    20.86
# 119                  Thomas Vinterberg                    98.0    16.48
# 137              Alejandro G. Iñárritu                   157.0    53.84
# 139                    Katsuhiro Ôtomo                   150.0     4.39
# 140                       José Padilha                   142.0     0.08
# 146                        Je-kyu Kang                    86.0    11.10
# 157                         Ari Folman                   231.0    22.83
# 160                      Walter Salles                    71.0    55.95
# 163                  Vincent Paronnaud                   242.0    44.43
# 188                        Karan Johar                   210.0    40.19
# 203                       Sergio Leone                   122.0    35.00
# 207                        Yash Chopra                    29.0    29.22
# 214               Christophe Barratier                   112.0    36.30
# 217                            Ang Lee                   287.0  1280.68
# 219                     Clint Eastwood                   251.0   137.54
# 230                     Michael Haneke                   447.0     2.25
# 240                        Yimou Zhang                   283.0     0.85
# 248                    Cristian Mungiu                   233.0    11.86
# 249                   Fabián Bielinsky                    94.0    12.21
#
#                                                  genres  \
# Rank
# 6                                               Western
# 17                               Action|Adventure|Drama
# 20                                          Crime|Drama
# 24                   Adventure|Animation|Family|Fantasy
# 36                                         Drama|Family
# 40                                       Drama|Thriller
# 50                                        Drama|Mystery
# 52                               Drama|Mystery|Thriller
# 54                                       Comedy|Romance
# 55                          Adventure|Animation|Fantasy
# 57                         Adventure|Drama|Thriller|War
# 59                   Action|Adventure|Drama|Fantasy|War
# 65                                                Drama
# 75                          Biography|Drama|History|War
# 82                                         Drama|Sci-Fi
# 86                   Adventure|Animation|Family|Fantasy
# 89                               Drama|Mystery|Thriller
# 98                                    Drama|Mystery|War
# 104                                   Drama|Fantasy|War
# 115                             Biography|Drama|Romance
# 119                                               Drama
# 137                                      Drama|Thriller
# 139                             Action|Animation|Sci-Fi
# 140                         Action|Crime|Drama|Thriller
# 146                                    Action|Drama|War
# 157   Animation|Biography|Documentary|Drama|History|War
# 160                                               Drama
# 163                       Animation|Biography|Drama|War
# 188                            Adventure|Drama|Thriller
# 203                                Action|Drama|Western
# 207                               Drama|Musical|Romance
# 214                                         Drama|Music
# 217                                Action|Drama|Romance
# 219                                   Drama|History|War
# 230                                       Drama|Romance
# 240                            Action|Adventure|History
# 248                                               Drama
# 249                                Crime|Drama|Thriller
#
#                actor_1_name                          movie_title  \
# Rank
# 6            Clint Eastwood      The Good, the Bad and the Ugly
# 17          Takashi Shimura                       Seven Samurai
# 20              Alice Braga                         City of God
# 24           Bunta Sugawara                       Spirited Away
# 36           Bahare Seddiqi                  Children of Heaven
# 40           Sebastian Koch                 The Lives of Others
# 50          Shahab Hosseini                        A Separation
# 52             Min-sik Choi                              Oldboy
# 54        Mathieu Kassovitz                              Amélie
# 248             44763                 172.0    Romanian     0.59      2007.0
# 249             38215                 125.0     Spanish     1.50      2000.0
#
#       imdb_score  movie_facebook_likes   Profit
# Rank
# 6            8.9                 20000    59.80
# 17           8.7                 11000     0.69
# 20           8.7                 28000    72.33
# 24           8.6                 28000    81.50
# 36           8.5                     0     9.07
# 40           8.5                 39000   110.85
# 50           8.4                 48000    70.48
# 52           8.4                 43000    18.81
# 54           8.4                 39000   255.02
# 55           8.4                 11000 -2377.02
# 57           8.4                 11000   100.33
# 59           8.4                 21000    46.95
# 65           8.3                 60000     2.31
# 75           8.3                 14000    41.52
# 82           8.3                 12000    -5.74
# 86           8.2                 13000    23.10
# 89           8.2                 33000   199.67
# 98           8.2                 37000    61.77
# 104          8.2                 27000   362.73
# 115          8.1                     0    10.86
# 119          8.1                  5000    15.18
# 137          8.1                 11000    51.84
# 139          8.1                     0 -1095.61
# 140          8.1                 11000    -3.92
# 146          8.1                     0    -1.70
# 157          8.0                     0    21.33
# 160          8.0                     0    53.05
# 163          8.0                 14000    37.13
# 188          8.0                 27000    28.19
# 203          8.0                     0    34.80
# 207          7.9                  2000    22.22
# 214          7.9                     0    30.80
# 217          7.9                     0  1265.68
# 219          7.9                  5000   118.54
# 230          7.9                 33000    -6.65
# 240          7.9                     0   -30.15
# 248          7.9                 14000    11.27
# 249          7.9                     0    10.71

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here
d_name = movies.groupby('director_name')

top10director = pd.DataFrame(d_name.imdb_score.mean())
top10director = top10director.sort_values(by = ['imdb_score','director_name'], ascending = False).head(10)
top10director
# Out:
#                    imdb_score
# director_name
# Tony Kaye            8.600000
# Charles Chaplin      8.600000
# Ron Fricke           8.500000
# Majid Majidi         8.500000
# Damien Chazelle      8.500000
# Alfred Hitchcock     8.500000
# Sergio Leone         8.433333
# Christopher Nolan    8.425000
# S.S. Rajamouli       8.400000
# Richard Marquand     8.400000

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
Genres = movies['genres'].str.split('|').apply(pd.Series)
Genres.columns = ['Genre1','Genre2','Genre3','Genre4','Genre5','Genre6','Genre7','Genre8']
Genres = Genres.drop(['Genre3','Genre4','Genre5','Genre6','Genre7','Genre8'], axis = 1)
Genres.loc[(pd.isnull(Genres.Genre2)), 'Genre2'] = Genres.Genre1 

movies = pd.concat([movies, Genres], axis = 1)
movies
# Out:
#           director_name  num_critic_for_reviews    gross  \
# 0         James Cameron                   723.0  7605.06
# 26        James Cameron                   315.0  6586.72
# 29      Colin Trevorrow                   644.0  6521.77
# 794         Joss Whedon                   703.0  6232.80
# 66    Christopher Nolan                   645.0  5333.16
# ...                 ...                     ...      ...
# 2334    Katsuhiro Ôtomo                   105.0     4.10
# 2323     Hayao Miyazaki                   174.0    22.98
# 3005       Lajos Koltai                    73.0     1.96
# 3859     Chan-wook Park                   202.0     2.12
# 2988       Joon-ho Bong                   363.0    22.01
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 26                                        Drama|Romance    Leonardo DiCaprio
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 794                             Action|Adventure|Sci-Fi      Chris Hemsworth
# 66                          Action|Crime|Drama|Thriller       Christian Bale
# ...                                                 ...                  ...
# 2334  Action|Adventure|Animation|Family|Sci-Fi|Thriller     William Hootkins
# 2323                        Adventure|Animation|Fantasy        Minnie Driver
# 3005                                  Drama|Romance|War         Marcell Nagy
# 3859                                        Crime|Drama         Min-sik Choi
# 2988                         Comedy|Drama|Horror|Sci-Fi            Doona Bae
#
#              movie_title  num_voted_users  num_user_for_reviews   language  \
# 0                Avatar            886204                3054.0    English
# 26              Titanic            793059                2528.0    English
# 29       Jurassic World            418214                1290.0    English
# 794        The Avengers            995415                1722.0    English
# 66      The Dark Knight           1676169                4667.0    English
# ...                  ...              ...                   ...        ...
# 2334           Steamboy             13727                  79.0   Japanese
# 2323  Princess Mononoke            221552                 570.0   Japanese
# 3005           Fateless              5603                  45.0  Hungarian
# 3859     Lady Vengeance             53508                 131.0     Korean
# 2988           The Host             68883                 279.0     Korean
#
#         budget  title_year  imdb_score  movie_facebook_likes    Profit  \
# 0       237.00      2009.0         7.9                 33000   7368.06
# 26      200.00      1997.0         7.7                 26000   6386.72
# 29      150.00      2015.0         7.0                150000   6371.77
# 794     220.00      2012.0         8.1                123000   6012.80
# 66      185.00      2008.0         9.0                 37000   5148.16
# ...        ...         ...         ...                   ...       ...
# 2334   2127.52      2004.0         6.9                   973  -2123.42
# 2323   2400.00      1997.0         8.4                 11000  -2377.02
# 3005   2500.00      2005.0         7.1                   607  -2498.04
# 3859   4200.00      2005.0         7.7                  4000  -4197.88
# 2988  12215.50      2006.0         7.0                  7000 -12193.49
#
#          Genre1     Genre2
# 0        Action  Adventure
# 26        Drama    Romance
# 29       Action  Adventure
# 794      Action  Adventure
# 66       Action      Crime
# ...         ...        ...
# 2334     Action  Adventure
# 2323  Adventure  Animation
# 3005      Drama    Romance
# 3859      Crime      Drama
# 2988     Comedy      Drama
#
# [3856 rows x 16 columns]

# %%
# Write your code for grouping the dataframe here
movies_by_segment = movies.groupby(['Genre1','Genre2'])
movies_by_segment

# %%
# Write your code for getting the 5 most popular combo of genres here
df = pd.DataFrame(movies_by_segment.gross.mean())
PopGenre = df.sort_values(by = 'gross', ascending = False).head() 
PopGenre
# Out:
#                            gross
# Genre1    Genre2
# Family    Sci-Fi     4349.490000
# Adventure Sci-Fi     2286.278750
#           Family     1189.196765
#           Animation  1169.985726
# Action    Adventure  1095.954490

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here
# Include all movies in which Meryl_Streep is the lead

Meryl_Streep = movies[movies['actor_1_name'] == 'Meryl Streep']
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews    gross  \
# 1408   David Frankel                   208.0  1247.33
# 410     Nancy Meyers                   187.0  1127.03
# 1204     Nora Ephron                   252.0   941.25
# 1575  Sydney Pollack                    66.0   871.00
# 1618   David Frankel                   234.0   635.36
# 1106   Curtis Hanson                    42.0   468.16
# 1925  Stephen Daldry                   174.0   415.98
# 2781  Phyllida Lloyd                   331.0   299.59
# 1674   Carl Franklin                    64.0   232.09
# 3135   Robert Altman                   211.0   203.39
# 1483  Robert Redford                   227.0   149.98
#
#                                genres  actor_1_name  \
# 1408             Comedy|Drama|Romance  Meryl Streep
# 410              Comedy|Drama|Romance  Meryl Streep
# 1204          Biography|Drama|Romance  Meryl Streep
# 1575          Biography|Drama|Romance  Meryl Streep
# 1618             Comedy|Drama|Romance  Meryl Streep
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep
# 1925                    Drama|Romance  Meryl Streep
# 2781          Biography|Drama|History  Meryl Streep
# 1674                            Drama  Meryl Streep
# 3135               Comedy|Drama|Music  Meryl Streep
# 1483               Drama|Thriller|War  Meryl Streep
#
#                     movie_title  num_voted_users  num_user_for_reviews  \
# 
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews    gross  \
# 400       Steven Soderbergh                   186.0  1834.06
# 255              Doug Liman                   233.0  1863.36
# 147       Wolfgang Petersen                   220.0  1332.28
# 254       Steven Soderbergh                   198.0  1255.32
# 101           David Fincher                   362.0  1274.91
# 940             Neil Jordan                   120.0  1052.65
# 470              David Ayer                   406.0   857.07
# 2204  Alejandro G. Iñárritu                   285.0   343.01
# 611     Jean-Jacques Annaud                    76.0   379.02
# 683           David Fincher                   315.0   370.23
# 792         Patrick Gilmore                    98.0   262.88
# 2682         Andrew Dominik                   414.0   149.39
# 2898             Tony Scott                   122.0   122.82
# 1490        Terrence Malick                   584.0   133.03
# 1722         Andrew Dominik                   273.0    39.05
# 2333    Angelina Jolie Pitt                   131.0     5.31
# 382              Tony Scott                   142.0     0.27
#
#                                                  genres actor_1_name  \
# 400                                      Crime|Thriller    Brad Pitt
# 255                Action|Comedy|Crime|Romance|Thriller    Brad Pitt
# 147                                           Adventure    Brad Pitt
# 254                                      Crime|Thriller    Brad Pitt
# 101                               Drama|Fantasy|Romance    Brad Pitt
# 940                                Drama|Fantasy|Horror    Brad Pitt
# 470                                    Action|Drama|War    Brad Pitt
# 2204                                              Drama    Brad Pitt
# 611               Adventure|Biography|Drama|History|War    Brad Pitt
# 683                                               Drama    Brad Pitt
# 792   Adventure|Animation|Comedy|Drama|Family|Fantas...    Brad Pitt
# 2682                                     Crime|Thriller    Brad Pitt
# 2898                Action|Crime|Drama|Romance|Thriller    Brad Pitt
# 1490                                      Drama|Fantasy    Brad Pitt
# 1722              Biography|Crime|Drama|History|Western    Brad Pitt
# 2333                                      Drama|Romance    Brad Pitt
# 382                               Action|Crime|Thriller    Brad Pitt
#
#                                             movie_title  num_voted_users  \
# 400                                     Ocean's Eleven            402645
# 255                                   Mr. & Mrs. Smith            348861
# 147                                               Troy            381672
# 254                                     Ocean's Twelve            284852
# 101                The Curious Case of Benjamin Button            459346
# 940   Interview with the Vampire: The Vampire Chroni...           239752
# 470                                               Fury            303185
# 2204                                             Babel            243799
# 611                               Seven Years in Tibet             96385
# 683                                         Fight Club           1347461
# 792                   Sinbad: Legend of the Seven Seas             36144
# 2682                               Killing Them Softly            111625
# 2898                                      True Romance            163492
# 1490                                  The Tree of Life            136367
# 1722  The Assassination of Jesse James by the Coward...           136104
# 2333                                        By the Sea              7976
# 382                                           Spy Game            121259
#
#       num_user_for_reviews language  budget  title_year  imdb_score  \
# 400                  845.0  English    85.0      2001.0         7.8
# 255                  798.0  English   120.0      2005.0         6.5
# 147                 1694.0  English   175.0      2004.0         7.2
# 254                  627.0  English   110.0      2004.0         6.4
# 101                  822.0  English   150.0      2008.0         7.8
# 940                  406.0  English    60.0      1994.0         7.6
# 470                  701.0  English    68.0      2014.0         7.6
# 2204                 908.0  English    25.0      2006.0         7.5
# 611                  119.0  English    70.0      1997.0         7.0
# 683                 2968.0  English    63.0      1999.0         8.8
# 792                   91.0  English    60.0      2003.0         6.7
# 2682                 369.0  English    15.0      2012.0         6.2
# 2898                 460.0  English    13.0      1993.0         8.0
# 1490                 975.0  English    32.0      2011.0         6.7
# 1722                 415.0  English    30.0      2007.0         7.5
# 2333                  61.0  English    10.0      2015.0         5.3
# 382                  361.0  English    92.0      2001.0         7.0
#
#       movie_facebook_likes   Profit     Genre1     Genre2
# 400                      0  1749.06      Crime   Thriller
# 255                      0  1743.36     Action     Comedy
# 147                      0  1157.28  Adventure  Adventure
# 254                      0  1145.32      Crime   Thriller
# 101                  23000  1124.91      Drama    Fantasy
# 940                  11000   992.65      Drama    Fantasy
# 470                  82000   789.07     Action      Drama
# 2204                     0   318.01      Drama      Drama
# 611                      0   309.02  Adventure  Biography
# 683                  48000   307.23      Drama      Drama
# 792                    880   202.88  Adventure  Animation
# 2682                 20000   134.39      Crime   Thriller
# 2898                 15000   109.82     Action      Crime
# 1490                 39000   101.03      Drama    Fantasy
# 1722                     0     9.05  Biography      Crime
# 2333                     0    -4.69      Drama    Romance
# 382                      0   -91.73     Action      Crime

# %%
# Write your code for combining the three dataframes here
Combined = Meryl_Streep.append([Leo_Caprio, Brad_Pitt])
Combined
# Out:
#               director_name  num_critic_for_reviews    gross  \
# 1575                     0   840.00  Biography      Drama
# 1618                     0   605.36     Comedy      Drama
# 1106                     0   423.16     Action  Adventure
# 1925                     0   390.98      Drama    Romance
# 2781                 18000   286.59  Biography      Drama
# 1674                   592   202.09      Drama      Drama
# 3135                   683   193.39     Comedy      Drama
# 1483                     0   114.98      Drama   Thriller
# 26                   26000  6386.72      Drama    Romance
# 97                  175000  2765.69     Action  Adventure
# 179                 190000  1701.36  Adventure      Drama
# 911                  15000  1592.35  Biography      Crime
# 296                 199000  1528.05      Drama    Western
# 3476                115000  1343.13      Drama    Romance
# 50                  115000  1343.13      Drama    Romance
# 361                  29000  1233.73      Crime      Drama
# 452                  53000  1199.68    Mystery   Thriller
# 308                 138000  1068.67  Biography     Comedy
# 257                      0   916.09  Biography      Drama
# 326                      0   676.80      Crime      Drama
# 1422                     0   533.76     Action  Adventure
# 307                  14000   473.66  Adventure      Drama
# 2757                 10000   448.89      Drama    Romance
# 990                      0   347.79  Adventure      Drama
# 1453                 16000   338.05  Biography      Crime
# 641                      0   323.80     Action      Drama
# 1114                     0   193.78      Drama    Romance
# 1560                     0   154.37     Action   Thriller
# 2067                  1000   104.83      Drama      Drama
# 400                      0  1749.06      Crime   Thriller
# 255                      0  1743.36     Action     Comedy
# 147                      0  1157.28  Adventure  Adventure
# 254                      0  1145.32      Crime   Thriller
# 101                  23000  1124.91      Drama    Fantasy
# 940                  11000   992.65      Drama    Fantasy
# 470                  82000   789.07     Action      Drama
# 2204                     0   318.01      Drama      Drama
# 611                      0   309.02  Adventure  Biography
# 683                  48000   307.23      Drama      Drama
# 792                    880   202.88  Adventure  Animation
# 2682                 20000   134.39      Crime   Thriller
# 2898                 15000   109.82     Action      Crime
# 1490                 39000   101.03      Drama    Fantasy
# 1722                     0     9.05  Biography      Crime
# 2333                     0    -4.69      Drama    Romance
# 382                      0   -91.73     Action      Crime

# %%
# Write your code for grouping the combined dataframe here
actor_movies = Combined.groupby('actor_1_name')
actor_movies

# %%
# Write the code for finding the mean of critic reviews and audience reviews here

critic_reviews = pd.DataFrame(actor_movies.num_critic_for_reviews.mean())
users_reviews = pd.DataFrame(actor_movies.num_user_for_reviews.mean())

#Identifying actors having highest mean.
highest = pd.concat([critic_reviews,users_reviews], axis = 1)
highest = highest.sort_values(by = ['num_critic_for_reviews', 'num_user_for_reviews'], ascending = False).head()
highest
# Out:
#                    num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Leonardo DiCaprio              330.190476            914.476190
# Brad Pitt                      245.000000            742.352941
# Meryl Streep                   181.454545            297.181818

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
movies['decade'] = movies['title_year']//10*10
movies['decade'] = pd.to_datetime(movies['decade'], format = '%Y').dt.strftime('%Ys')
movies = movies.sort_values(by = 'decade')
movies
# Out:
#           director_name  num_critic_for_reviews    gross  \
# 2734         Fritz Lang                   260.0     0.26
# 4812     Harry Beaumont                    36.0    28.08
# 4958  Harry F. Millarde                     1.0    30.00
# 4157     Victor Fleming                   213.0   222.03
# 4449   William Cottrell                   145.0  1849.25
# ...                 ...                     ...      ...
# 4197     James Ponsoldt                   220.0    68.52
# 1496    Robert Zemeckis                   335.0   101.38
# 1317       Pierre Morel                   224.0   106.41
# 2174      Steve McQueen                   597.0   566.68
# 322     Paul Greengrass                   266.0   350.24
#
#                                    genres          actor_1_name  \
# 2734                         Drama|Sci-Fi         Brigitte Helm
# 4812                      Musical|Romance            Anita Page
# 4958                          Crime|Drama          Stephen Carr
# 4157     Adventure|Family|Fantasy|Musical     Margaret Hamilton
# 4449     Animation|Family|Fantasy|Musical     Adriana Caselotti
# ...                                   ...                   ...
# 4197                 Comedy|Drama|Romance      Shailene Woodley
# 1496   Adventure|Biography|Drama|Thriller  Joseph Gordon-Levitt
# 1317  Action|Crime|Drama|Mystery|Thriller          Ray Winstone
# 2174              Biography|Drama|History     Quvenzhané Wallis
# 322             Action|Drama|Thriller|War            Matt Damon
#
#                            movie_title  num_voted_users  num_user_for_reviews  \
# 2734                       Metropolis            111841                 413.0
# 4812              The Broadway Melody              4546                  71.0
# 4958   Over the Hill to the Poorhouse                 5                   1.0
# 4157                 The Wizard of Oz            291875                 533.0
# 4449  Snow White and the Seven Dwarfs            133348                 204.0
# ...                                ...              ...                   ...
# 4197              The Spectacular Now            105591                 178.0
# 1496                         The Walk             77394                 195.0
# 1317                       The Gunman             28429                 110.0
# 2174                 12 Years a Slave            439176                 695.0
# 322                        Green Zone            110364                 261.0
#
#      language  budget  title_year  imdb_score  movie_facebook_likes   Profit  \
# 2734   German    6.00      1927.0         8.3                 12000    -5.74
# 4812  English    0.38      1929.0         6.3                   167    27.70
# 4958  English    0.10      1920.0         4.8                     0    29.90
# 4157  English    2.80      1939.0         8.1                 14000   219.23
# 4449  English    2.00      1937.0         7.7                     0  1847.25
# ...       ...     ...         ...         ...                   ...      ...
# 4197  English    2.50      2013.0         7.1                 10000    66.02
# 1496  English   35.00      2015.0         7.4                 24000    66.38
# 1317  English   40.00      2015.0         5.8                     0    66.41
# 2174  English   20.00      2013.0         8.1                 83000   546.68
# 322   English  100.00      2010.0         6.9                     0   250.24
#
#          Genre1     Genre2 decade
# 2734      Drama     Sci-Fi  1920s
# 4812    Musical    Romance  1920s
# 4958      Crime      Drama  1920s
# 4157  Adventure     Family  1930s
# 4449  Animation     Family  1930s
# ...         ...        ...    ...
# 4197     Comedy      Drama  2010s
# 1496  Adventure  Biography  2010s
# 1317     Action      Crime  2010s
# 2174  Biography      Drama  2010s
# 322      Action      Drama  2010s
#
# [3856 rows x 17 columns]

# %%
# Write your code for creating the data frame df_by_decade here 
dgroup = movies.groupby('decade')
df_by_decade = pd.DataFrame(dgroup.num_voted_users.sum())
df_by_decade = df_by_decade.reset_index() #removing 'decade' from index column.
df_by_decade
# Out:
#   decade  num_voted_users
# 0  1920s           116392
# 1  1930s           804839
# 2  1940s           230838
# 3  1950s           678336
# 4  1960s          2983442
# 5  1970s          8524102
# 6  1980s         19987476
# 7  1990s         69735679
# 8  2000s        170908676
# 9  2010s        120640994

# %%
# Write your code for plotting number of voted users vs decade
plt.figure(figsize=(10, 8))
sns.barplot(x='decade', y='num_voted_users', data=df_by_decade)
plt.title('number of voted users vs decade')

plt.show()

# %% [markdown]
# We observe that the Number of Voted users were:
# -  Low till the 1980's.
# -  Had increased in 1990's.
# -  and Massively Increased in 2000's.
